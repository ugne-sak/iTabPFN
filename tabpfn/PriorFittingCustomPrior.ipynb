# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload

# %autoreload 2

# %%
import random
import time
import warnings
from datetime import datetime

import torch

import numpy as np

import matplotlib.pyplot as plt
#from scripts.differentiable_pfn_evaluation import eval_model_range
# No string
from scripts.model_builder import get_model, get_default_spec, save_model, load_model
from scripts.transformer_prediction_interface import transformer_predict, get_params_from_config, load_model_workflow

from scripts.model_configs import *

from datasets import load_openml_list, open_cc_dids, open_cc_valid_dids
from priors.utils import plot_prior, plot_features
from priors.utils import uniform_int_sampler_f

from scripts.tabular_metrics import calculate_score_per_method, calculate_score
# No string
#from scripts.tabular_evaluation import evaluate

from priors.differentiable_prior import DifferentiableHyperparameterList, draw_random_style, merge_style_with_info
from scripts import tabular_metrics
from notebook_utils import *

# %%
large_datasets = True
max_samples = 10000 if large_datasets else 5000
bptt = 10000 if large_datasets else 3000
suite='cc'

# %%
device = 'cpu'
base_path = '.'
max_features = 100

# %%
def print_models(model_string):
    print(model_string)

    for i in range(80):
        for e in range(50):
            exists = Path(os.path.join(base_path, f'models_diff/prior_diff_real_checkpoint{model_string}_n_{i}_epoch_{e}.cpkt')).is_file()
            if exists:
                print(os.path.join(base_path, f'models_diff/prior_diff_real_checkpoint{model_string}_n_{i}_epoch_{e}.cpkt'))
        print()

# %%
def train_function(config_sample, i, add_name=''):
    start_time = time.time()
    N_epochs_to_save = 50
    
    def save_callback(model, epoch):
        if not hasattr(model, 'last_saved_epoch'):
            model.last_saved_epoch = 0
        if ((time.time() - start_time) / (maximum_runtime * 60 / N_epochs_to_save)) > model.last_saved_epoch:
            print('Saving model..')
            config_sample['epoch_in_training'] = epoch
            save_model(model, base_path, f'models_diff/prior_diff_real_checkpoint{add_name}_n_{i}_epoch_{model.last_saved_epoch}.cpkt',
                           config_sample)
            model.last_saved_epoch = model.last_saved_epoch + 1 # TODO: Rename to checkpoint
    
    model = get_model(config_sample
                      , device
                      , should_train=True
                      , verbose=1
                      , epoch_callback = save_callback)
    
    return

# %% [markdown]
# ## Define prior settings

# %%
def reload_config(config_type='causal', task_type='multiclass', longer=0):
    config = get_prior_config(config_type=config_type)
    
    config['prior_type'], config['differentiable'], config['flexible'] = 'prior_bag', True, True
    
    model_string = ''
    
    config['epochs'] = 12000
    config['recompute_attn'] = True

    config['max_num_classes'] = 10
    config['num_classes'] = uniform_int_sampler_f(2, config['max_num_classes'])
    config['balanced'] = False
    model_string = model_string + '_multiclass'
    
    model_string = model_string + '_'+datetime.now().strftime("%m_%d_%Y_%H_%M_%S")
    
    return config, model_string

# %% [markdown]
# ## Visualize Prior samples

# %%
config, model_string = reload_config(longer=1)

config['bptt_extra_samples'] = None

# diff
config['output_multiclass_ordered_p'] = 0.
del config['differentiable_hyperparameters']['output_multiclass_ordered_p']

config['multiclass_type'] = 'rank'
del config['differentiable_hyperparameters']['multiclass_type']

config['sampling'] = 'normal' # vielleicht schlecht?
del config['differentiable_hyperparameters']['sampling']

config['pre_sample_causes'] = True
# end diff

config['multiclass_loss_type'] = 'nono' # 'compatible'
config['normalize_to_ranking'] = False # False

config['categorical_feature_p'] = .2 # diff: .0

# turn this back on in a random search!?
config['nan_prob_no_reason'] = .0
config['nan_prob_unknown_reason'] = .0 # diff: .0
config['set_value_to_nan'] = .1 # diff: 1.

config['normalize_with_sqrt'] = False

config['new_mlp_per_example'] = True
config['prior_mlp_scale_weights_sqrt'] = True
config['batch_size_per_gp_sample'] = None

config['normalize_ignore_label_too'] = False

config['differentiable_hps_as_style'] = False
config['max_eval_pos'] = 1000

config['random_feature_rotation'] = True
config['rotate_normalized_labels'] = True

config["mix_activations"] = False # False heisst eig True

config['emsize'] = 16
config['nhead'] = config['emsize'] // 8
config['bptt'] = 1024+128
config['canonical_y_encoder'] = False

    
config['aggregate_k_gradients'] = 8
config['batch_size'] = 8*config['aggregate_k_gradients']
config['num_steps'] = 1024//config['aggregate_k_gradients']
config['epochs'] = 400
config['total_available_time_in_s'] = None #60*60*22 # 22 hours for some safety...

config['train_mixed_precision'] = True
config['efficient_eval_masking'] = True

config_sample = evaluate_hypers(config)

# %%
config_sample['batch_size'] = 4
model = get_model(config_sample, device, should_train=False, verbose=2) # , state_dict=model[2].state_dict()
(hp_embedding, data, _), targets, single_eval_pos = next(iter(model[3]))

from utils import normalize_data
fig = plt.figure(figsize=(8, 8))
N = 100
plot_features(data[0:N, 0, 0:4], targets[0:N, 0], fig=fig)

d = np.concatenate([data[:, 0, :].T, np.expand_dims(targets[:, 0], -1).T])
d[np.isnan(d)] = 0
c = np.corrcoef(d)
plt.matshow(np.abs(c), vmin=0, vmax=1)
plt.show()
# Out:
# Using style prior: True
# Using cpu:0 device
# Using a Transformer with 2.44 M parameters
# PRIOR_BAG: tensor([1.0000, 4.0245]) [1]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/0q/4mgwbnlj0tj34_6lyhzrbs5c0000gn/T/ipykernel_83827/1379447198.py in <module>
#       1 config_sample['batch_size'] = 4
#       2 model = get_model(config_sample, device, should_train=False, verbose=2) # , state_dict=model[2].state_dict()
# ----> 3 (hp_embedding, data, _), targets, single_eval_pos = next(iter(model[3]))
#       4
#       5 from utils import normalize_data
#
# ~/GitRepo/TabPFN/tabpfn/priors/utils.py in <genexpr>(.0)
#      45             assert hasattr(self, 'model'), "Please assign model with `dl.model = ...` before training."
#      46             self.epoch_count += 1
# ---> 47             return iter(self.gbm(**self.get_batch_kwargs, epoch=self.epoch_count - 1, model=self.model) for _ in range(self.num_steps))
#      48
#      49     return DL
#
# ~/GitRepo/TabPFN/tabpfn/priors/utils.py in gbm(eval_pos_seq_len_sampler, *args, **kwargs)
#      32             if 'dynamic_batch_size' in kwargs and kwargs['dynamic_batch_size'] > 0 and kwargs['dynamic_batch_size']:
#      33                 kwargs['batch_size'] = kwargs['batch_size'] * math.floor(math.pow(kwargs['seq_len_maximum'], kwargs['dynamic_batch_size']) / math.pow(kwargs['seq_len'], kwargs['dynamic_batch_size']))
# ---> 34             batch = get_batch_method_(*args, **kwargs)
#      35             x, y, target_y, style = batch if len(batch) == 4 else (batch[0], batch[1], batch[2], None)
#      36             return (style, x, y), target_y, kwargs['single_eval_pos']
#
# ~/opt/anaconda3/envs/TabPFN/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/GitRepo/TabPFN/tabpfn/priors/differentiable_prior.py in get_batch(batch_size, seq_len, num_features, get_batch, device, differentiable_hyperparameters, hyperparameters, batch_size_per_gp_sample, **kwargs)
#     238
#     239     models = [DifferentiablePrior(get_batch, hyperparameters, differentiable_hyperparameters, args) for _ in range(num_models)]
# --> 240     sample = sum([[model()] for model in models], [])
#     241
#     242     x, y, y_, hyperparameter_dict = zip(*sample)
#
# ~/GitRepo/TabPFN/tabpfn/priors/differentiable_prior.py in <listcomp>(.0)
#     238
#     239     models = [DifferentiablePrior(get_batch, hyperparameters, differentiable_hyperparameters, args) for _ in range(num_models)]
# --> 240     sample = sum([[model()] for model in models], [])
#     241
#     242     x, y, y_, hyperparameter_dict = zip(*sample)
#
# ~/opt/anaconda3/envs/TabPFN/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/GitRepo/TabPFN/tabpfn/priors/differentiable_prior.py in forward(self)
#     220
#     221         hyperparameters = {**self.h, **sampled_hyperparameters_passed}
# --> 222         x, y, y_ = self.get_batch(hyperparameters=hyperparameters, **self.args)
#     223
#     224         return x, y, y_, sampled_hyperparameters_indicators
#
# ~/GitRepo/TabPFN/tabpfn/scripts/model_builder.py in new_get_batch(batch_size, seq_len, num_features, hyperparameters, device, model_proto, **kwargs)
#     223                 , device=device
#     224                 , hyperparameters=hyperparameters
# --> 225                 , num_features=num_features, **kwargs)
#     226         return new_get_batch
#     227
#
# ~/GitRepo/TabPFN/tabpfn/priors/prior_bag.py in get_batch(batch_size, seq_len, num_features, device, hyperparameters, batch_size_per_gp_sample, **kwargs)
#      24         print('PRIOR_BAG:', weights, batch_assignments)
#      25
# ---> 26     sample = [prior_bag_priors_get_batch[int(prior_idx)](hyperparameters=hyperparameters, **args, **kwargs) for prior_idx in batch_assignments]
#      27
#      28     x, y, y_ = zip(*sample)
#
# ~/GitRepo/TabPFN/tabpfn/priors/prior_bag.py in <listcomp>(.0)
#      24         print('PRIOR_BAG:', weights, batch_assignments)
#      25
# ---> 26     sample = [prior_bag_priors_get_batch[int(prior_idx)](hyperparameters=hyperparameters, **args, **kwargs) for prior_idx in batch_assignments]
#      27
#      28     x, y, y_ = zip(*sample)
#
# ~/GitRepo/TabPFN/tabpfn/scripts/model_builder.py in new_get_batch(batch_size, seq_len, num_features, hyperparameters, device, model_proto, **kwargs)
#     223                 , device=device
#     224                 , hyperparameters=hyperparameters
# --> 225                 , num_features=num_features, **kwargs)
#     226         return new_get_batch
#     227
#
# ~/opt/anaconda3/envs/TabPFN/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/GitRepo/TabPFN/tabpfn/priors/flexible_categorical.py in get_batch(batch_size, seq_len, num_features, get_batch, device, hyperparameters, batch_size_per_gp_sample, **kwargs)
#     262     models = [FlexibleCategorical(get_batch, hyperparameters, args).to(device) for _ in range(num_models)]
#     263
# --> 264     sample = [model(batch_size=batch_size_per_gp_sample) for model in models]
#     265
#     266     x, y, y_ = zip(*sample)
#
# ~/GitRepo/TabPFN/tabpfn/priors/flexible_categorical.py in <listcomp>(.0)
#     262     models = [FlexibleCategorical(get_batch, hyperparameters, args).to(device) for _ in range(num_models)]
#     263
# --> 264     sample = [model(batch_size=batch_size_per_gp_sample) for model in models]
#     265
#     266     x, y, y_ = zip(*sample)
#
# ~/opt/anaconda3/envs/TabPFN/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/GitRepo/TabPFN/tabpfn/priors/flexible_categorical.py in forward(self, batch_size)
#     146     def forward(self, batch_size):
#     147         start = time.time()
# --> 148         x, y, y_ = self.get_batch(hyperparameters=self.h, **self.args_passed)
#     149         if time_it:
#     150             print('Flex Forward Block 1', round(time.time() - start, 3))
#
# ~/GitRepo/TabPFN/tabpfn/scripts/model_builder.py in new_get_batch(batch_size, seq_len, num_features, hyperparameters, device, model_proto, **kwargs)
#     223                 , device=device
#     224                 , hyperparameters=hyperparameters
# --> 225                 , num_features=num_features, **kwargs)
#     226         return new_get_batch
#     227
#
# ~/GitRepo/TabPFN/tabpfn/priors/mlp.py in get_batch(batch_size, seq_len, num_features, hyperparameters, device, num_outputs, sampling, epoch, **kwargs)
#     179         get_model = lambda: model
#     180
# --> 181     sample = [get_model()() for _ in range(0, batch_size)]
#     182
#     183     x, y = zip(*sample)
#
# ~/GitRepo/TabPFN/tabpfn/priors/mlp.py in <listcomp>(.0)
#     179         get_model = lambda: model
#     180
# --> 181     sample = [get_model()() for _ in range(0, batch_size)]
#     182
#     183     x, y = zip(*sample)
#
# ~/GitRepo/TabPFN/tabpfn/priors/mlp.py in <lambda>()
#     174
#     175     if hyperparameters.get('new_mlp_per_example', False):
# --> 176         get_model = lambda: MLP(hyperparameters).to(device)
#     177     else:
#     178         model = MLP(hyperparameters).to(device)
#
# ~/GitRepo/TabPFN/tabpfn/priors/mlp.py in __init__(self, hyperparameters)
#      48
#      49                 if 'verbose' in hyperparameters and self.verbose:
# ---> 50                     print({k : hyperparameters[k] for k in ['#', 'num_causes', 'prior_mlp_hidden_dim'
#      51                         , 'num_layers', 'noise_std', 'y_is_effect', 'pre_sample_weights', 'prior_mlp_dropout_prob'
#      52                         , 'pre_sample_causes']})
#
# ~/GitRepo/TabPFN/tabpfn/priors/mlp.py in <dictcomp>(.0)
#      48
#      49                 if 'verbose' in hyperparameters and self.verbose:
# ---> 50                     print({k : hyperparameters[k] for k in ['#', 'num_causes', 'prior_mlp_hidden_dim'
#      51                         , 'num_layers', 'noise_std', 'y_is_effect', 'pre_sample_weights', 'prior_mlp_dropout_prob'
#      52                         , 'pre_sample_causes']})
#
# KeyError: '#'

# %% [markdown]
# ## Training

# %%
model = get_model(config_sample, device, should_train=True, verbose=1)
# Out:
# Using style prior: True
# Using cpu:0 device
# Using a Transformer with 0.04 M parameters
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 124
# running forward \
# Single eval position: 124
# running forward \
# Single eval position: 124
# running forward \
# Single eval position: 124
# running forward \
# Single eval position: 124
# running forward \
# Single eval position: 124
# running forward \
# Single eval position: 124
# running forward \
# Single eval position: 124
# running forward \
# Single eval position: 124
# running forward \
# Single eval position: 124
# running forward \
# Single eval position: 124
# running forward \
# Single eval position: 124
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 838
# running forward \
# Single eval position: 838
# running forward \
# Single eval position: 838
# running forward \
# Single eval position: 838
# running forward \
# Single eval position: 838
# running forward \
# Single eval position: 838
# running forward \
# Single eval position: 838
# running forward \
# Single eval position: 838
# running forward \
# Single eval position: 838
# running forward \
# Single eval position: 838
# running forward \
# Single eval position: 838
# running forward \
# Single eval position: 838
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 235
# running forward \
# Single eval position: 235
# running forward \
# Single eval position: 235
# running forward \
# Single eval position: 235
# running forward \
# Single eval position: 235
# running forward \
# Single eval position: 235
# running forward \
# Single eval position: 235
# running forward \
# Single eval position: 235
# running forward \
# Single eval position: 235
# running forward \
# Single eval position: 235
# running forward \
# Single eval position: 235
# running forward \
# Single eval position: 235
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 39
# running forward \
# Single eval position: 39
# running forward \
# Single eval position: 39
# running forward \
# Single eval position: 39
# running forward \
# Single eval position: 39
# running forward \
# Single eval position: 39
# running forward \
# Single eval position: 39
# running forward \
# Single eval position: 39
# running forward \
# Single eval position: 39
# running forward \
# Single eval position: 39
# running forward \
# Single eval position: 39
# running forward \
# Single eval position: 39
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 328
# running forward \
# Single eval position: 328
# running forward \
# Single eval position: 328
# running forward \
# Single eval position: 328
# running forward \
# Single eval position: 328
# running forward \
# Single eval position: 328
# running forward \
# Single eval position: 328
# running forward \
# Single eval position: 328
# running forward \
# Single eval position: 328
# running forward \
# Single eval position: 328
# running forward \
# Single eval position: 328
# running forward \
# Single eval position: 328
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 70
# running forward \
# Single eval position: 70
# running forward \
# Single eval position: 70
# running forward \
# Single eval position: 70
# running forward \
# Single eval position: 70
# running forward \
# Single eval position: 70
# running forward \
# Single eval position: 70
# running forward \
# Single eval position: 70
# running forward \
# Single eval position: 70
# running forward \
# Single eval position: 70
# running forward \
# Single eval position: 70
# running forward \
# Single eval position: 70
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 539
# running forward \
# Single eval position: 539
# running forward \
# Single eval position: 539
# running forward \
# Single eval position: 539
# running forward \
# Single eval position: 539
# running forward \
# Single eval position: 539
# running forward \
# Single eval position: 539
# running forward \
# Single eval position: 539
# running forward \
# Single eval position: 539
# running forward \
# Single eval position: 539
# running forward \
# Single eval position: 539
# running forward \
# Single eval position: 539
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 589
# running forward \
# Single eval position: 589
# running forward \
# Single eval position: 589
# running forward \
# Single eval position: 589
# running forward \
# Single eval position: 589
# running forward \
# Single eval position: 589
# running forward \
# Single eval position: 589
# running forward \
# Single eval position: 589
# running forward \
# Single eval position: 589
# running forward \
# Single eval position: 589
# running forward \
# Single eval position: 589
# running forward \
# Single eval position: 589
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 554
# running forward \
# Single eval position: 554
# running forward \
# Single eval position: 554
# running forward \
# Single eval position: 554
# running forward \
# Single eval position: 554
# running forward \
# Single eval position: 554
# running forward \
# Single eval position: 554
# running forward \
# Single eval position: 554
# running forward \
# Single eval position: 554
# running forward \
# Single eval position: 554
# running forward \
# Single eval position: 554
# running forward \
# Single eval position: 554
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 597
# running forward \
# Single eval position: 597
# running forward \
# Single eval position: 597
# running forward \
# Single eval position: 597
# running forward \
# Single eval position: 597
# running forward \
# Single eval position: 597
# running forward \
# Single eval position: 597
# running forward \
# Single eval position: 597
# running forward \
# Single eval position: 597
# running forward \
# Single eval position: 597
# running forward \
# Single eval position: 597
# running forward \
# Single eval position: 597
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 986
# running forward \
# Single eval position: 986
# running forward \
# Single eval position: 986
# running forward \
# Single eval position: 986
# running forward \
# Single eval position: 986
# running forward \
# Single eval position: 986
# running forward \
# Single eval position: 986
# running forward \
# Single eval position: 986
# running forward \
# Single eval position: 986
# running forward \
# Single eval position: 986
# running forward \
# Single eval position: 986
# running forward \
# Single eval position: 986
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 57
# running forward \
# Single eval position: 57
# running forward \
# Single eval position: 57
# running forward \
# Single eval position: 57
# running forward \
# Single eval position: 57
# running forward \
# Single eval position: 57
# running forward \
# Single eval position: 57
# running forward \
# Single eval position: 57
# running forward \
# Single eval position: 57
# running forward \
# Single eval position: 57
# running forward \
# Single eval position: 57
# running forward \
# Single eval position: 57
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 296
# running forward \
# Single eval position: 296
# running forward \
# Single eval position: 296
# running forward \
# Single eval position: 296
# running forward \
# Single eval position: 296
# running forward \
# Single eval position: 296
# running forward \
# Single eval position: 296
# running forward \
# Single eval position: 296
# running forward \
# Single eval position: 296
# running forward \
# Single eval position: 296
# running forward \
# Single eval position: 296
# running forward \
# Single eval position: 296
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 779
# running forward \
# Single eval position: 779
# running forward \
# Single eval position: 779
# running forward \
# Single eval position: 779
# running forward \
# Single eval position: 779
# running forward \
# Single eval position: 779
# running forward \
# Single eval position: 779
# running forward \
# Single eval position: 779
# running forward \
# Single eval position: 779
# running forward \
# Single eval position: 779
# running forward \
# Single eval position: 779
# running forward \
# Single eval position: 779
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 619
# running forward \
# Single eval position: 619
# running forward \
# Single eval position: 619
# running forward \
# Single eval position: 619
# running forward \
# Single eval position: 619
# running forward \
# Single eval position: 619
# running forward \
# Single eval position: 619
# running forward \
# Single eval position: 619
# running forward \
# Single eval position: 619
# running forward \
# Single eval position: 619
# running forward \
# Single eval position: 619
# running forward \
# Single eval position: 619
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 108
# running forward \
# Single eval position: 108
# running forward \
# Single eval position: 108
# running forward \
# Single eval position: 108
# running forward \
# Single eval position: 108
# running forward \
# Single eval position: 108
# running forward \
# Single eval position: 108
# running forward \
# Single eval position: 108
# running forward \
# Single eval position: 108
# running forward \
# Single eval position: 108
# running forward \
# Single eval position: 108
# running forward \
# Single eval position: 108
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 965
# running forward \
# Single eval position: 965
# running forward \
# Single eval position: 965
# running forward \
# Single eval position: 965
# running forward \
# Single eval position: 965
# running forward \
# Single eval position: 965
# running forward \
# Single eval position: 965
# running forward \
# Single eval position: 965
# running forward \
# Single eval position: 965
# running forward \
# Single eval position: 965
# running forward \
# Single eval position: 965
# running forward \
# Single eval position: 965
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 872
# running forward \
# Single eval position: 872
# running forward \
# Single eval position: 872
# running forward \
# Single eval position: 872
# running forward \
# Single eval position: 872
# running forward \
# Single eval position: 872
# running forward \
# Single eval position: 872
# running forward \
# Single eval position: 872
# running forward \
# Single eval position: 872
# running forward \
# Single eval position: 872
# running forward \
# Single eval position: 872
# running forward \
# Single eval position: 872
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 911
# running forward \
# Single eval position: 911
# running forward \
# Single eval position: 911
# running forward \
# Single eval position: 911
# running forward \
# Single eval position: 911
# running forward \
# Single eval position: 911
# running forward \
# Single eval position: 911
# running forward \
# Single eval position: 911
# running forward \
# Single eval position: 911
# running forward \
# Single eval position: 911
# running forward \
# Single eval position: 911
# running forward \
# Single eval position: 911
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 787
# running forward \
# Single eval position: 787
# running forward \
# Single eval position: 787
# running forward \
# Single eval position: 787
# running forward \
# Single eval position: 787
# running forward \
# Single eval position: 787
# running forward \
# Single eval position: 787
# running forward \
# Single eval position: 787
# running forward \
# Single eval position: 787
# running forward \
# Single eval position: 787
# running forward \
# Single eval position: 787
# running forward \
# Single eval position: 787
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 141
# running forward \
# Single eval position: 141
# running forward \
# Single eval position: 141
# running forward \
# Single eval position: 141
# running forward \
# Single eval position: 141
# running forward \
# Single eval position: 141
# running forward \
# Single eval position: 141
# running forward \
# Single eval position: 141
# running forward \
# Single eval position: 141
# running forward \
# Single eval position: 141
# running forward \
# Single eval position: 141
# running forward \
# Single eval position: 141
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 275
# running forward \
# Single eval position: 275
# running forward \
# Single eval position: 275
# running forward \
# Single eval position: 275
# running forward \
# Single eval position: 275
# running forward \
# Single eval position: 275
# running forward \
# Single eval position: 275
# running forward \
# Single eval position: 275
# running forward \
# Single eval position: 275
# running forward \
# Single eval position: 275
# running forward \
# Single eval position: 275
# running forward \
# Single eval position: 275
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 799
# running forward \
# Single eval position: 799
# running forward \
# Single eval position: 799
# running forward \
# Single eval position: 799
# running forward \
# Single eval position: 799
# running forward \
# Single eval position: 799
# running forward \
# Single eval position: 799
# running forward \
# Single eval position: 799
# running forward \
# Single eval position: 799
# running forward \
# Single eval position: 799
# running forward \
# Single eval position: 799
# running forward \
# Single eval position: 799
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 178
# running forward \
# Single eval position: 178
# running forward \
# Single eval position: 178
# running forward \
# Single eval position: 178
# running forward \
# Single eval position: 178
# running forward \
# Single eval position: 178
# running forward \
# Single eval position: 178
# running forward \
# Single eval position: 178
# running forward \
# Single eval position: 178
# running forward \
# Single eval position: 178
# running forward \
# Single eval position: 178
# running forward \
# Single eval position: 178
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 229
# running forward \
# Single eval position: 229
# running forward \
# Single eval position: 229
# running forward \
# Single eval position: 229
# running forward \
# Single eval position: 229
# running forward \
# Single eval position: 229
# running forward \
# Single eval position: 229
# running forward \
# Single eval position: 229
# running forward \
# Single eval position: 229
# running forward \
# Single eval position: 229
# running forward \
# Single eval position: 229
# running forward \
# Single eval position: 229
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 140
# running forward \
# Single eval position: 140
# running forward \
# Single eval position: 140
# running forward \
# Single eval position: 140
# running forward \
# Single eval position: 140
# running forward \
# Single eval position: 140
# running forward \
# Single eval position: 140
# running forward \
# Single eval position: 140
# running forward \
# Single eval position: 140
# running forward \
# Single eval position: 140
# running forward \
# Single eval position: 140
# running forward \
# Single eval position: 140
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 867
# running forward \
# Single eval position: 867
# running forward \
# Single eval position: 867
# running forward \
# Single eval position: 867
# running forward \
# Single eval position: 867
# running forward \
# Single eval position: 867
# running forward \
# Single eval position: 867
# running forward \
# Single eval position: 867
# running forward \
# Single eval position: 867
# running forward \
# Single eval position: 867
# running forward \
# Single eval position: 867
# running forward \
# Single eval position: 867
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 32
# running forward \
# Single eval position: 32
# running forward \
# Single eval position: 32
# running forward \
# Single eval position: 32
# running forward \
# Single eval position: 32
# running forward \
# Single eval position: 32
# running forward \
# Single eval position: 32
# running forward \
# Single eval position: 32
# running forward \
# Single eval position: 32
# running forward \
# Single eval position: 32
# running forward \
# Single eval position: 32
# running forward \
# Single eval position: 32
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 530
# running forward \
# Single eval position: 530
# running forward \
# Single eval position: 530
# running forward \
# Single eval position: 530
# running forward \
# Single eval position: 530
# running forward \
# Single eval position: 530
# running forward \
# Single eval position: 530
# running forward \
# Single eval position: 530
# running forward \
# Single eval position: 530
# running forward \
# Single eval position: 530
# running forward \
# Single eval position: 530
# running forward \
# Single eval position: 530
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 547
# running forward \
# Single eval position: 547
# running forward \
# Single eval position: 547
# running forward \
# Single eval position: 547
# running forward \
# Single eval position: 547
# running forward \
# Single eval position: 547
# running forward \
# Single eval position: 547
# running forward \
# Single eval position: 547
# running forward \
# Single eval position: 547
# running forward \
# Single eval position: 547
# running forward \
# Single eval position: 547
# running forward \
# Single eval position: 547
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 923
# running forward \
# Single eval position: 923
# running forward \
# Single eval position: 923
# running forward \
# Single eval position: 923
# running forward \
# Single eval position: 923
# running forward \
# Single eval position: 923
# running forward \
# Single eval position: 923
# running forward \
# Single eval position: 923
# running forward \
# Single eval position: 923
# running forward \
# Single eval position: 923
# running forward \
# Single eval position: 923
# running forward \
# Single eval position: 923
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 203
# running forward \
# Single eval position: 203
# running forward \
# Single eval position: 203
# running forward \
# Single eval position: 203
# running forward \
# Single eval position: 203
# running forward \
# Single eval position: 203
# running forward \
# Single eval position: 203
# running forward \
# Single eval position: 203
# running forward \
# Single eval position: 203
# running forward \
# Single eval position: 203
# running forward \
# Single eval position: 203
# running forward \
# Single eval position: 203
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 126
# running forward \
# Single eval position: 126
# running forward \
# Single eval position: 126
# running forward \
# Single eval position: 126
# running forward \
# Single eval position: 126
# running forward \
# Single eval position: 126
# running forward \
# Single eval position: 126
# running forward \
# Single eval position: 126
# running forward \
# Single eval position: 126
# running forward \
# Single eval position: 126
# running forward \
# Single eval position: 126
# running forward \
# Single eval position: 126
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 880
# running forward \
# Single eval position: 880
# running forward \
# Single eval position: 880
# running forward \
# Single eval position: 880
# running forward \
# Single eval position: 880
# running forward \
# Single eval position: 880
# running forward \
# Single eval position: 880
# running forward \
# Single eval position: 880
# running forward \
# Single eval position: 880
# running forward \
# Single eval position: 880
# running forward \
# Single eval position: 880
# running forward \
# Single eval position: 880
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 941
# running forward \
# Single eval position: 941
# running forward \
# Single eval position: 941
# running forward \
# Single eval position: 941
# running forward \
# Single eval position: 941
# running forward \
# Single eval position: 941
# running forward \
# Single eval position: 941
# running forward \
# Single eval position: 941
# running forward \
# Single eval position: 941
# running forward \
# Single eval position: 941
# running forward \
# Single eval position: 941
# running forward \
# Single eval position: 941
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 35
# running forward \
# Single eval position: 35
# running forward \
# Single eval position: 35
# running forward \
# Single eval position: 35
# running forward \
# Single eval position: 35
# running forward \
# Single eval position: 35
# running forward \
# Single eval position: 35
# running forward \
# Single eval position: 35
# running forward \
# Single eval position: 35
# running forward \
# Single eval position: 35
# running forward \
# Single eval position: 35
# running forward \
# Single eval position: 35
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 387
# running forward \
# Single eval position: 387
# running forward \
# Single eval position: 387
# running forward \
# Single eval position: 387
# running forward \
# Single eval position: 387
# running forward \
# Single eval position: 387
# running forward \
# Single eval position: 387
# running forward \
# Single eval position: 387
# running forward \
# Single eval position: 387
# running forward \
# Single eval position: 387
# running forward \
# Single eval position: 387
# running forward \
# Single eval position: 387
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 67
# running forward \
# Single eval position: 67
# running forward \
# Single eval position: 67
# running forward \
# Single eval position: 67
# running forward \
# Single eval position: 67
# running forward \
# Single eval position: 67
# running forward \
# Single eval position: 67
# running forward \
# Single eval position: 67
# running forward \
# Single eval position: 67
# running forward \
# Single eval position: 67
# running forward \
# Single eval position: 67
# running forward \
# Single eval position: 67
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 453
# running forward \
# Single eval position: 453
# running forward \
# Single eval position: 453
# running forward \
# Single eval position: 453
# running forward \
# Single eval position: 453
# running forward \
# Single eval position: 453
# running forward \
# Single eval position: 453
# running forward \
# Single eval position: 453
# running forward \
# Single eval position: 453
# running forward \
# Single eval position: 453
# running forward \
# Single eval position: 453
# running forward \
# Single eval position: 453
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 766
# running forward \
# Single eval position: 766
# running forward \
# Single eval position: 766
# running forward \
# Single eval position: 766
# running forward \
# Single eval position: 766
# running forward \
# Single eval position: 766
# running forward \
# Single eval position: 766
# running forward \
# Single eval position: 766
# running forward \
# Single eval position: 766
# running forward \
# Single eval position: 766
# running forward \
# Single eval position: 766
# running forward \
# Single eval position: 766
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# running forward \
# Single eval position: 201
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 585
# running forward \
# Single eval position: 585
# running forward \
# Single eval position: 585
# running forward \
# Single eval position: 585
# running forward \
# Single eval position: 585
# running forward \
# Single eval position: 585
# running forward \
# Single eval position: 585
# running forward \
# Single eval position: 585
# running forward \
# Single eval position: 585
# running forward \
# Single eval position: 585
# running forward \
# Single eval position: 585
# running forward \
# Single eval position: 585
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 339
# running forward \
# Single eval position: 339
# running forward \
# Single eval position: 339
# running forward \
# Single eval position: 339
# running forward \
# Single eval position: 339
# running forward \
# Single eval position: 339
# running forward \
# Single eval position: 339
# running forward \
# Single eval position: 339
# running forward \
# Single eval position: 339
# running forward \
# Single eval position: 339
# running forward \
# Single eval position: 339
# running forward \
# Single eval position: 339
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 245
# running forward \
# Single eval position: 245
# running forward \
# Single eval position: 245
# running forward \
# Single eval position: 245
# running forward \
# Single eval position: 245
# running forward \
# Single eval position: 245
# running forward \
# Single eval position: 245
# running forward \
# Single eval position: 245
# running forward \
# Single eval position: 245
# running forward \
# Single eval position: 245
# running forward \
# Single eval position: 245
# running forward \
# Single eval position: 245
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 678
# running forward \
# Single eval position: 678
# running forward \
# Single eval position: 678
# running forward \
# Single eval position: 678
# running forward \
# Single eval position: 678
# running forward \
# Single eval position: 678
# running forward \
# Single eval position: 678
# running forward \
# Single eval position: 678
# running forward \
# Single eval position: 678
# running forward \
# Single eval position: 678
# running forward \
# Single eval position: 678
# running forward \
# Single eval position: 678
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 154
# running forward \
# Single eval position: 154
# running forward \
# Single eval position: 154
# running forward \
# Single eval position: 154
# running forward \
# Single eval position: 154
# running forward \
# Single eval position: 154
# running forward \
# Single eval position: 154
# running forward \
# Single eval position: 154
# running forward \
# Single eval position: 154
# running forward \
# Single eval position: 154
# running forward \
# Single eval position: 154
# running forward \
# Single eval position: 154
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 775
# running forward \
# Single eval position: 775
# running forward \
# Single eval position: 775
# running forward \
# Single eval position: 775
# running forward \
# Single eval position: 775
# running forward \
# Single eval position: 775
# running forward \
# Single eval position: 775
# running forward \
# Single eval position: 775
# running forward \
# Single eval position: 775
# running forward \
# Single eval position: 775
# running forward \
# Single eval position: 775
# running forward \
# Single eval position: 775
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 811
# running forward \
# Single eval position: 811
# running forward \
# Single eval position: 811
# running forward \
# Single eval position: 811
# running forward \
# Single eval position: 811
# running forward \
# Single eval position: 811
# running forward \
# Single eval position: 811
# running forward \
# Single eval position: 811
# running forward \
# Single eval position: 811
# running forward \
# Single eval position: 811
# running forward \
# Single eval position: 811
# running forward \
# Single eval position: 811
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# running forward \
# Single eval position: 670
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 681
# running forward \
# Single eval position: 681
# running forward \
# Single eval position: 681
# running forward \
# Single eval position: 681
# running forward \
# Single eval position: 681
# running forward \
# Single eval position: 681
# running forward \
# Single eval position: 681
# running forward \
# Single eval position: 681
# running forward \
# Single eval position: 681
# running forward \
# Single eval position: 681
# running forward \
# Single eval position: 681
# running forward \
# Single eval position: 681
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 647
# running forward \
# Single eval position: 647
# running forward \
# Single eval position: 647
# running forward \
# Single eval position: 647
# running forward \
# Single eval position: 647
# running forward \
# Single eval position: 647
# running forward \
# Single eval position: 647
# running forward \
# Single eval position: 647
# running forward \
# Single eval position: 647
# running forward \
# Single eval position: 647
# running forward \
# Single eval position: 647
# running forward \
# Single eval position: 647
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 916
# running forward \
# Single eval position: 916
# running forward \
# Single eval position: 916
# running forward \
# Single eval position: 916
# running forward \
# Single eval position: 916
# running forward \
# Single eval position: 916
# running forward \
# Single eval position: 916
# running forward \
# Single eval position: 916
# running forward \
# Single eval position: 916
# running forward \
# Single eval position: 916
# running forward \
# Single eval position: 916
# running forward \
# Single eval position: 916
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 441
# running forward \
# Single eval position: 441
# running forward \
# Single eval position: 441
# running forward \
# Single eval position: 441
# running forward \
# Single eval position: 441
# running forward \
# Single eval position: 441
# running forward \
# Single eval position: 441
# running forward \
# Single eval position: 441
# running forward \
# Single eval position: 441
# running forward \
# Single eval position: 441
# running forward \
# Single eval position: 441
# running forward \
# Single eval position: 441
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 982
# running forward \
# Single eval position: 982
# running forward \
# Single eval position: 982
# running forward \
# Single eval position: 982
# running forward \
# Single eval position: 982
# running forward \
# Single eval position: 982
# running forward \
# Single eval position: 982
# running forward \
# Single eval position: 982
# running forward \
# Single eval position: 982
# running forward \
# Single eval position: 982
# running forward \
# Single eval position: 982
# running forward \
# Single eval position: 982
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 366
# running forward \
# Single eval position: 366
# running forward \
# Single eval position: 366
# running forward \
# Single eval position: 366
# running forward \
# Single eval position: 366
# running forward \
# Single eval position: 366
# running forward \
# Single eval position: 366
# running forward \
# Single eval position: 366
# running forward \
# Single eval position: 366
# running forward \
# Single eval position: 366
# running forward \
# Single eval position: 366
# running forward \
# Single eval position: 366
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 392
# running forward \
# Single eval position: 392
# running forward \
# Single eval position: 392
# running forward \
# Single eval position: 392
# running forward \
# Single eval position: 392
# running forward \
# Single eval position: 392
# running forward \
# Single eval position: 392
# running forward \
# Single eval position: 392
# running forward \
# Single eval position: 392
# running forward \
# Single eval position: 392
# running forward \
# Single eval position: 392
# running forward \
# Single eval position: 392
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 777
# running forward \
# Single eval position: 777
# running forward \
# Single eval position: 777
# running forward \
# Single eval position: 777
# running forward \
# Single eval position: 777
# running forward \
# Single eval position: 777
# running forward \
# Single eval position: 777
# running forward \
# Single eval position: 777
# running forward \
# Single eval position: 777
# running forward \
# Single eval position: 777
# running forward \
# Single eval position: 777
# running forward \
# Single eval position: 777
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 714
# running forward \
# Single eval position: 714
# running forward \
# Single eval position: 714
# running forward \
# Single eval position: 714
# running forward \
# Single eval position: 714
# running forward \
# Single eval position: 714
# running forward \
# Single eval position: 714
# running forward \
# Single eval position: 714
# running forward \
# Single eval position: 714
# running forward \
# Single eval position: 714
# running forward \
# Single eval position: 714
# running forward \
# Single eval position: 714
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 661
# running forward \
# Single eval position: 661
# running forward \
# Single eval position: 661
# running forward \
# Single eval position: 661
# running forward \
# Single eval position: 661
# running forward \
# Single eval position: 661
# running forward \
# Single eval position: 661
# running forward \
# Single eval position: 661
# running forward \
# Single eval position: 661
# running forward \
# Single eval position: 661
# running forward \
# Single eval position: 661
# running forward \
# Single eval position: 661
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 406
# running forward \
# Single eval position: 406
# running forward \
# Single eval position: 406
# running forward \
# Single eval position: 406
# running forward \
# Single eval position: 406
# running forward \
# Single eval position: 406
# running forward \
# Single eval position: 406
# running forward \
# Single eval position: 406
# running forward \
# Single eval position: 406
# running forward \
# Single eval position: 406
# running forward \
# Single eval position: 406
# running forward \
# Single eval position: 406
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 36
# running forward \
# Single eval position: 36
# running forward \
# Single eval position: 36
# running forward \
# Single eval position: 36
# running forward \
# Single eval position: 36
# running forward \
# Single eval position: 36
# running forward \
# Single eval position: 36
# running forward \
# Single eval position: 36
# running forward \
# Single eval position: 36
# running forward \
# Single eval position: 36
# running forward \
# Single eval position: 36
# running forward \
# Single eval position: 36
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 352
# running forward \
# Single eval position: 352
# running forward \
# Single eval position: 352
# running forward \
# Single eval position: 352
# running forward \
# Single eval position: 352
# running forward \
# Single eval position: 352
# running forward \
# Single eval position: 352
# running forward \
# Single eval position: 352
# running forward \
# Single eval position: 352
# running forward \
# Single eval position: 352
# running forward \
# Single eval position: 352
# running forward \
# Single eval position: 352
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 142
# running forward \
# Single eval position: 142
# running forward \
# Single eval position: 142
# running forward \
# Single eval position: 142
# running forward \
# Single eval position: 142
# running forward \
# Single eval position: 142
# running forward \
# Single eval position: 142
# running forward \
# Single eval position: 142
# running forward \
# Single eval position: 142
# running forward \
# Single eval position: 142
# running forward \
# Single eval position: 142
# running forward \
# Single eval position: 142
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 372
# running forward \
# Single eval position: 372
# running forward \
# Single eval position: 372
# running forward \
# Single eval position: 372
# running forward \
# Single eval position: 372
# running forward \
# Single eval position: 372
# running forward \
# Single eval position: 372
# running forward \
# Single eval position: 372
# running forward \
# Single eval position: 372
# running forward \
# Single eval position: 372
# running forward \
# Single eval position: 372
# running forward \
# Single eval position: 372
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 776
# running forward \
# Single eval position: 776
# running forward \
# Single eval position: 776
# running forward \
# Single eval position: 776
# running forward \
# Single eval position: 776
# running forward \
# Single eval position: 776
# running forward \
# Single eval position: 776
# running forward \
# Single eval position: 776
# running forward \
# Single eval position: 776
# running forward \
# Single eval position: 776
# running forward \
# Single eval position: 776
# running forward \
# Single eval position: 776
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 323
# running forward \
# Single eval position: 323
# running forward \
# Single eval position: 323
# running forward \
# Single eval position: 323
# running forward \
# Single eval position: 323
# running forward \
# Single eval position: 323
# running forward \
# Single eval position: 323
# running forward \
# Single eval position: 323
# running forward \
# Single eval position: 323
# running forward \
# Single eval position: 323
# running forward \
# Single eval position: 323
# running forward \
# Single eval position: 323
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 161
# running forward \
# Single eval position: 161
# running forward \
# Single eval position: 161
# running forward \
# Single eval position: 161
# running forward \
# Single eval position: 161
# running forward \
# Single eval position: 161
# running forward \
# Single eval position: 161
# running forward \
# Single eval position: 161
# running forward \
# Single eval position: 161
# running forward \
# Single eval position: 161
# running forward \
# Single eval position: 161
# running forward \
# Single eval position: 161
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 832
# running forward \
# Single eval position: 832
# running forward \
# Single eval position: 832
# running forward \
# Single eval position: 832
# running forward \
# Single eval position: 832
# running forward \
# Single eval position: 832
# running forward \
# Single eval position: 832
# running forward \
# Single eval position: 832
# running forward \
# Single eval position: 832
# running forward \
# Single eval position: 832
# running forward \
# Single eval position: 832
# running forward \
# Single eval position: 832
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 562
# running forward \
# Single eval position: 562
# running forward \
# Single eval position: 562
# running forward \
# Single eval position: 562
# running forward \
# Single eval position: 562
# running forward \
# Single eval position: 562
# running forward \
# Single eval position: 562
# running forward \
# Single eval position: 562
# running forward \
# Single eval position: 562
# running forward \
# Single eval position: 562
# running forward \
# Single eval position: 562
# running forward \
# Single eval position: 562
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 512
# running forward \
# Single eval position: 512
# running forward \
# Single eval position: 512
# running forward \
# Single eval position: 512
# running forward \
# Single eval position: 512
# running forward \
# Single eval position: 512
# running forward \
# Single eval position: 512
# running forward \
# Single eval position: 512
# running forward \
# Single eval position: 512
# running forward \
# Single eval position: 512
# running forward \
# Single eval position: 512
# running forward \
# Single eval position: 512
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 607
# running forward \
# Single eval position: 607
# running forward \
# Single eval position: 607
# running forward \
# Single eval position: 607
# running forward \
# Single eval position: 607
# running forward \
# Single eval position: 607
# running forward \
# Single eval position: 607
# running forward \
# Single eval position: 607
# running forward \
# Single eval position: 607
# running forward \
# Single eval position: 607
# running forward \
# Single eval position: 607
# running forward \
# Single eval position: 607
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 824
# running forward \
# Single eval position: 824
# running forward \
# Single eval position: 824
# running forward \
# Single eval position: 824
# running forward \
# Single eval position: 824
# running forward \
# Single eval position: 824
# running forward \
# Single eval position: 824
# running forward \
# Single eval position: 824
# running forward \
# Single eval position: 824
# running forward \
# Single eval position: 824
# running forward \
# Single eval position: 824
# running forward \
# Single eval position: 824
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 665
# running forward \
# Single eval position: 665
# running forward \
# Single eval position: 665
# running forward \
# Single eval position: 665
# running forward \
# Single eval position: 665
# running forward \
# Single eval position: 665
# running forward \
# Single eval position: 665
# running forward \
# Single eval position: 665
# running forward \
# Single eval position: 665
# running forward \
# Single eval position: 665
# running forward \
# Single eval position: 665
# running forward \
# Single eval position: 665
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 423
# running forward \
# Single eval position: 423
# running forward \
# Single eval position: 423
# running forward \
# Single eval position: 423
# running forward \
# Single eval position: 423
# running forward \
# Single eval position: 423
# running forward \
# Single eval position: 423
# running forward \
# Single eval position: 423
# running forward \
# Single eval position: 423
# running forward \
# Single eval position: 423
# running forward \
# Single eval position: 423
# running forward \
# Single eval position: 423
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 471
# running forward \
# Single eval position: 471
# running forward \
# Single eval position: 471
# running forward \
# Single eval position: 471
# running forward \
# Single eval position: 471
# running forward \
# Single eval position: 471
# running forward \
# Single eval position: 471
# running forward \
# Single eval position: 471
# running forward \
# Single eval position: 471
# running forward \
# Single eval position: 471
# running forward \
# Single eval position: 471
# running forward \
# Single eval position: 471
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 222
# running forward \
# Single eval position: 222
# running forward \
# Single eval position: 222
# running forward \
# Single eval position: 222
# running forward \
# Single eval position: 222
# running forward \
# Single eval position: 222
# running forward \
# Single eval position: 222
# running forward \
# Single eval position: 222
# running forward \
# Single eval position: 222
# running forward \
# Single eval position: 222
# running forward \
# Single eval position: 222
# running forward \
# Single eval position: 222
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 227
# ...
# running forward \
# Single eval position: 14
# running forward \
# Single eval position: 14
# running forward \
# Single eval position: 14
# running forward \
# Single eval position: 14
# running forward \
# Single eval position: 14
# running forward \
# Single eval position: 14
# running forward \
# Single eval position: 14
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 924
# running forward \
# Single eval position: 924
# running forward \
# Single eval position: 924
# running forward \
# Single eval position: 924
# running forward \
# Single eval position: 924
# running forward \
# Single eval position: 924
# running forward \
# Single eval position: 924
# running forward \
# Single eval position: 924
# running forward \
# Single eval position: 924
# running forward \
# Single eval position: 924
# running forward \
# Single eval position: 924
# running forward \
# Single eval position: 924
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 254
# running forward \
# Single eval position: 254
# running forward \
# Single eval position: 254
# running forward \
# Single eval position: 254
# running forward \
# Single eval position: 254
# running forward \
# Single eval position: 254
# running forward \
# Single eval position: 254
# running forward \
# Single eval position: 254
# running forward \
# Single eval position: 254
# running forward \
# Single eval position: 254
# running forward \
# Single eval position: 254
# running forward \
# Single eval position: 254
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 9
# running forward \
# Single eval position: 9
# running forward \
# Single eval position: 9
# running forward \
# Single eval position: 9
# running forward \
# Single eval position: 9
# running forward \
# Single eval position: 9
# running forward \
# Single eval position: 9
# running forward \
# Single eval position: 9
# running forward \
# Single eval position: 9
# running forward \
# Single eval position: 9
# running forward \
# Single eval position: 9
# running forward \
# Single eval position: 9
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 616
# running forward \
# Single eval position: 616
# running forward \
# Single eval position: 616
# running forward \
# Single eval position: 616
# running forward \
# Single eval position: 616
# running forward \
# Single eval position: 616
# running forward \
# Single eval position: 616
# running forward \
# Single eval position: 616
# running forward \
# Single eval position: 616
# running forward \
# Single eval position: 616
# running forward \
# Single eval position: 616
# running forward \
# Single eval position: 616
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 999
# running forward \
# Single eval position: 999
# running forward \
# Single eval position: 999
# running forward \
# Single eval position: 999
# running forward \
# Single eval position: 999
# running forward \
# Single eval position: 999
# running forward \
# Single eval position: 999
# running forward \
# Single eval position: 999
# running forward \
# Single eval position: 999
# running forward \
# Single eval position: 999
# running forward \
# Single eval position: 999
# running forward \
# Single eval position: 999
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 535
# running forward \
# Single eval position: 535
# running forward \
# Single eval position: 535
# running forward \
# Single eval position: 535
# running forward \
# Single eval position: 535
# running forward \
# Single eval position: 535
# running forward \
# Single eval position: 535
# running forward \
# Single eval position: 535
# running forward \
# Single eval position: 535
# running forward \
# Single eval position: 535
# running forward \
# Single eval position: 535
# running forward \
# Single eval position: 535
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 253
# running forward \
# Single eval position: 253
# running forward \
# Single eval position: 253
# running forward \
# Single eval position: 253
# running forward \
# Single eval position: 253
# running forward \
# Single eval position: 253
# running forward \
# Single eval position: 253
# running forward \
# Single eval position: 253
# running forward \
# Single eval position: 253
# running forward \
# Single eval position: 253
# running forward \
# Single eval position: 253
# running forward \
# Single eval position: 253
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 160
# running forward \
# Single eval position: 160
# running forward \
# Single eval position: 160
# running forward \
# Single eval position: 160
# running forward \
# Single eval position: 160
# running forward \
# Single eval position: 160
# running forward \
# Single eval position: 160
# running forward \
# Single eval position: 160
# running forward \
# Single eval position: 160
# running forward \
# Single eval position: 160
# running forward \
# Single eval position: 160
# running forward \
# Single eval position: 160
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 962
# running forward \
# Single eval position: 962
# running forward \
# Single eval position: 962
# running forward \
# Single eval position: 962
# running forward \
# Single eval position: 962
# running forward \
# Single eval position: 962
# running forward \
# Single eval position: 962
# running forward \
# Single eval position: 962
# running forward \
# Single eval position: 962
# running forward \
# Single eval position: 962
# running forward \
# Single eval position: 962
# running forward \
# Single eval position: 962
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 118
# running forward \
# Single eval position: 118
# running forward \
# Single eval position: 118
# running forward \
# Single eval position: 118
# running forward \
# Single eval position: 118
# running forward \
# Single eval position: 118
# running forward \
# Single eval position: 118
# running forward \
# Single eval position: 118
# running forward \
# Single eval position: 118
# running forward \
# Single eval position: 118
# running forward \
# Single eval position: 118
# running forward \
# Single eval position: 118
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 586
# running forward \
# Single eval position: 586
# running forward \
# Single eval position: 586
# running forward \
# Single eval position: 586
# running forward \
# Single eval position: 586
# running forward \
# Single eval position: 586
# running forward \
# Single eval position: 586
# running forward \
# Single eval position: 586
# running forward \
# Single eval position: 586
# running forward \
# Single eval position: 586
# running forward \
# Single eval position: 586
# running forward \
# Single eval position: 586
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 466
# running forward \
# Single eval position: 466
# running forward \
# Single eval position: 466
# running forward \
# Single eval position: 466
# running forward \
# Single eval position: 466
# running forward \
# Single eval position: 466
# running forward \
# Single eval position: 466
# running forward \
# Single eval position: 466
# running forward \
# Single eval position: 466
# running forward \
# Single eval position: 466
# running forward \
# Single eval position: 466
# running forward \
# Single eval position: 466
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 794
# running forward \
# Single eval position: 794
# running forward \
# Single eval position: 794
# running forward \
# Single eval position: 794
# running forward \
# Single eval position: 794
# running forward \
# Single eval position: 794
# running forward \
# Single eval position: 794
# running forward \
# Single eval position: 794
# running forward \
# Single eval position: 794
# running forward \
# Single eval position: 794
# running forward \
# Single eval position: 794
# running forward \
# Single eval position: 794
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 733
# running forward \
# Single eval position: 733
# running forward \
# Single eval position: 733
# running forward \
# Single eval position: 733
# running forward \
# Single eval position: 733
# running forward \
# Single eval position: 733
# running forward \
# Single eval position: 733
# running forward \
# Single eval position: 733
# running forward \
# Single eval position: 733
# running forward \
# Single eval position: 733
# running forward \
# Single eval position: 733
# running forward \
# Single eval position: 733
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 107
# running forward \
# Single eval position: 107
# running forward \
# Single eval position: 107
# running forward \
# Single eval position: 107
# running forward \
# Single eval position: 107
# running forward \
# Single eval position: 107
# running forward \
# Single eval position: 107
# running forward \
# Single eval position: 107
# running forward \
# Single eval position: 107
# running forward \
# Single eval position: 107
# running forward \
# Single eval position: 107
# running forward \
# Single eval position: 107
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 248
# running forward \
# Single eval position: 248
# running forward \
# Single eval position: 248
# running forward \
# Single eval position: 248
# running forward \
# Single eval position: 248
# running forward \
# Single eval position: 248
# running forward \
# Single eval position: 248
# running forward \
# Single eval position: 248
# running forward \
# Single eval position: 248
# running forward \
# Single eval position: 248
# running forward \
# Single eval position: 248
# running forward \
# Single eval position: 248
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 753
# running forward \
# Single eval position: 753
# running forward \
# Single eval position: 753
# running forward \
# Single eval position: 753
# running forward \
# Single eval position: 753
# running forward \
# Single eval position: 753
# running forward \
# Single eval position: 753
# running forward \
# Single eval position: 753
# running forward \
# Single eval position: 753
# running forward \
# Single eval position: 753
# running forward \
# Single eval position: 753
# running forward \
# Single eval position: 753
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 430
# running forward \
# Single eval position: 430
# running forward \
# Single eval position: 430
# running forward \
# Single eval position: 430
# running forward \
# Single eval position: 430
# running forward \
# Single eval position: 430
# running forward \
# Single eval position: 430
# running forward \
# Single eval position: 430
# running forward \
# Single eval position: 430
# running forward \
# Single eval position: 430
# running forward \
# Single eval position: 430
# running forward \
# Single eval position: 430
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 162
# running forward \
# Single eval position: 162
# running forward \
# Single eval position: 162
# running forward \
# Single eval position: 162
# running forward \
# Single eval position: 162
# running forward \
# Single eval position: 162
# running forward \
# Single eval position: 162
# running forward \
# Single eval position: 162
# running forward \
# Single eval position: 162
# running forward \
# Single eval position: 162
# running forward \
# Single eval position: 162
# running forward \
# Single eval position: 162
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 448
# running forward \
# Single eval position: 448
# running forward \
# Single eval position: 448
# running forward \
# Single eval position: 448
# running forward \
# Single eval position: 448
# running forward \
# Single eval position: 448
# running forward \
# Single eval position: 448
# running forward \
# Single eval position: 448
# running forward \
# Single eval position: 448
# running forward \
# Single eval position: 448
# running forward \
# Single eval position: 448
# running forward \
# Single eval position: 448
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 358
# running forward \
# Single eval position: 358
# running forward \
# Single eval position: 358
# running forward \
# Single eval position: 358
# running forward \
# Single eval position: 358
# running forward \
# Single eval position: 358
# running forward \
# Single eval position: 358
# running forward \
# Single eval position: 358
# running forward \
# Single eval position: 358
# running forward \
# Single eval position: 358
# running forward \
# Single eval position: 358
# running forward \
# Single eval position: 358
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 365
# running forward \
# Single eval position: 365
# running forward \
# Single eval position: 365
# running forward \
# Single eval position: 365
# running forward \
# Single eval position: 365
# running forward \
# Single eval position: 365
# running forward \
# Single eval position: 365
# running forward \
# Single eval position: 365
# running forward \
# Single eval position: 365
# running forward \
# Single eval position: 365
# running forward \
# Single eval position: 365
# running forward \
# Single eval position: 365
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 336
# running forward \
# Single eval position: 336
# running forward \
# Single eval position: 336
# running forward \
# Single eval position: 336
# running forward \
# Single eval position: 336
# running forward \
# Single eval position: 336
# running forward \
# Single eval position: 336
# running forward \
# Single eval position: 336
# running forward \
# Single eval position: 336
# running forward \
# Single eval position: 336
# running forward \
# Single eval position: 336
# running forward \
# Single eval position: 336
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 478
# running forward \
# Single eval position: 478
# running forward \
# Single eval position: 478
# running forward \
# Single eval position: 478
# running forward \
# Single eval position: 478
# running forward \
# Single eval position: 478
# running forward \
# Single eval position: 478
# running forward \
# Single eval position: 478
# running forward \
# Single eval position: 478
# running forward \
# Single eval position: 478
# running forward \
# Single eval position: 478
# running forward \
# Single eval position: 478
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 63
# running forward \
# Single eval position: 63
# running forward \
# Single eval position: 63
# running forward \
# Single eval position: 63
# running forward \
# Single eval position: 63
# running forward \
# Single eval position: 63
# running forward \
# Single eval position: 63
# running forward \
# Single eval position: 63
# running forward \
# Single eval position: 63
# running forward \
# Single eval position: 63
# running forward \
# Single eval position: 63
# running forward \
# Single eval position: 63
# This is the size of x_src:torch.Size([1152, 8, 16])
# torch.Size([1152, 8, 16])
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
# running forward \
# Single eval position: 967
