# %%
from transformer import *
from encoders import *
import torch

# %%
transformer = TransformerModel(encoder = StyleEncoder(10, 64), n_out = 10, ninp = 64, nhead = 8, nhid = 2, nlayers = 1, dropout=0.0, 
                 style_encoder=None, y_encoder=StyleEncoder(1, 64),
                 pos_encoder=None, decoder=None, input_normalization=False, init_method=None, pre_norm=False,
                 activation='gelu', recompute_attn=False, num_global_att_tokens=0, full_attention=False,
                 all_layers_same_init=False, efficient_eval_masking=True)

# %%
input = (torch.rand([100, 10]), torch.rand([100, 1]))
transformer(input, single_eval_pos = 99).size()
# Out:
# This is the size of x_src:torch.Size([100, 64])
# torch.Size([100, 64])
# running forward \
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-57f99d8136ec> in <module>
#       1 input = (torch.rand([100, 10]), torch.rand([100, 1]))
# ----> 2 transformer(input, single_eval_pos = 99).size()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/GitRepo/TabPFN/tabpfn/transformer.py in forward(self, src, src_mask, single_eval_pos)
#     204             src = self.pos_encoder(src)
#     205
# --> 206         output = self.transformer_encoder(src, src_mask)
#     207         output = self.decoder(output)
#     208         return output[single_eval_pos+len(style_src)+(self.global_att_embeddings.num_embeddings if self.global_att_embeddings else 0):]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/GitRepo/TabPFN/tabpfn/transformer.py in forward(self, src, mask, src_key_padding_mask)
#     290
#     291         for mod in self.layers:
# --> 292             output = mod(output, src_mask=mask, src_key_padding_mask=src_key_padding_mask)
#     293
#     294         if self.norm is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/GitRepo/TabPFN/tabpfn/layer.py in forward(self, src, src_mask, src_key_padding_mask)
#     131
#     132         elif isinstance(src_mask, int): # NOT RUN - AssertionError
# --> 133             assert src_key_padding_mask is None # AssertionError when src_key_padding_mask=None --> so src_key_padding_mask must be not None (but it is None - default None is not changed)
#     134             single_eval_position = src_mask
#     135
#
# IndexError: too many indices for tensor of dimension 2

# %%
lin = nn.Linear(10, 64)(torch.rand([10, 10, 10]))
eval = 9


mult = nn.MultiheadAttention(embed_dim=64, num_heads = 8, batch_first=True)
mult(lin[:, eval:, :], lin[:, :eval, :], lin[:, :eval, :])[0].size()
# Out:
# torch.Size([10, 1, 64])

# %%
lin.size()[1]
# Out:
# 10
